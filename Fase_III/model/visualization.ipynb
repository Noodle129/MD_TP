# %% [markdown]
# # Visualização de Dados

# %% [markdown]
# ## Imports

# %%
import sklearn as skl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.gridspec import GridSpec
import scipy.stats as stats

# %%
dataset_name = "../model/datasets/FINALDATASET.csv"
braga_data = pd.read_csv(dataset_name)

# %% [markdown]
# ## Características Gerais

# %%
braga_data.head()
# Out:
#    longitude   latitude   no2  pm10  pm25  pm1        date      time  tempmax  \
# 0  -8.296389  41.449722  32.9  15.0   NaN  NaN  2020-01-01  00:00:00     55.4
# 1  -8.296389  41.449722  34.1  15.0   NaN  NaN  2020-01-01  01:00:00     55.4
# 2  -8.296389  41.449722  45.2  15.0   NaN  NaN  2020-01-01  02:00:00     55.4
# 3  -8.296389  41.449722  44.3   NaN   NaN  NaN  2020-01-01  03:00:00     55.4
# 4  -8.296389  41.449722  34.1   NaN   NaN  NaN  2020-01-01  04:00:00     55.4
#
#    tempmin  ...  severerisk  precip  snow  windspeed  sealevelpressure  \
# 0     50.2  ...        10.0    0.32   0.0       16.9            1018.9
# 1     50.2  ...        10.0    0.32   0.0       16.9            1018.9
# 2     50.2  ...        10.0    0.32   0.0       16.9            1018.9
# 3     50.2  ...        10.0    0.32   0.0       16.9            1018.9
# 4     50.2  ...        10.0    0.32   0.0       16.9            1018.9
#
#    cloudcover  visibility  solarradiation  solarenergy  uvindex
# 0        93.9         5.3            51.9          4.5      3.0
# 1        93.9         5.3            51.9          4.5      3.0
# 2        93.9         5.3            51.9          4.5      3.0
# 3        93.9         5.3            51.9          4.5      3.0
# 4        93.9         5.3            51.9          4.5      3.0
#
# [5 rows x 24 columns]

# %%
braga_data.describe()
# Out:
#           longitude      latitude           no2           pm10        pm25  \
# count  19198.000000  19198.000000  15287.000000   13761.000000  863.000000
# mean      -8.308660     41.461493     32.634644      26.298475    6.954102
# std        0.046299      0.042790     17.247468    1176.930893    7.653003
# min       -8.587790     41.449722      0.000000       0.000000    0.100000
# 25%       -8.296389     41.449722     19.900000      10.000000    2.495000
# 50%       -8.296389     41.449722     29.600000      15.000000    4.300000
# 75%       -8.296389     41.449722     41.800000      21.000000    8.200000
# max       -8.296389     41.653315    153.600000  138074.000000   60.730000
#
#               pm1       tempmax       tempmin          temp     feelslike  \
# count  266.000000  19198.000000  19198.000000  19198.000000  19198.000000
# mean     6.973233     61.804917     51.710553     56.671596     56.491556
# std      6.952309      8.057026      5.340165      6.149625      6.375273
# min      0.100000     46.700000     30.000000     37.300000     33.300000
# 25%      3.090000     55.400000     50.200000     52.800000     52.800000
# 50%      4.780000     58.000000     50.200000     53.500000     53.400000
# 75%      8.357500     67.700000     54.200000     61.500000     61.500000
# max     53.280000     97.700000     75.300000     84.900000     84.300000
#
#        ...    severerisk        precip     snow     windspeed  \
# count  ...  19198.000000  19198.000000  19198.0  19198.000000
# mean   ...     11.116783      0.188394      0.0     13.963356
# std    ...      7.378776      0.186891      0.0      4.830321
# min    ...     10.000000      0.000000      0.0      4.300000
# 25%    ...     10.000000      0.000000      0.0      8.700000
# 50%    ...     10.000000      0.130000      0.0     15.700000
# 75%    ...     10.000000      0.320000      0.0     16.900000
# max    ...     60.000000      1.687000      0.0     33.600000
#
#        sealevelpressure    cloudcover    visibility  solarradiation  \
# count      19198.000000  19198.000000  19198.000000    19198.000000
# mean        1018.584759     67.092968      6.025586      137.681847
# std            5.133461     32.197491      1.065719      111.079516
# min          996.800000      0.000000      1.100000        8.600000
# 25%         1016.700000     38.400000      5.300000       51.900000
# 50%         1018.900000     90.600000      5.300000       51.900000
# 75%         1019.200000     93.900000      6.800000      238.300000
# max         1034.900000     99.500000      9.000000      361.700000
#
#         solarenergy       uvindex
# count  19198.000000  19198.000000
# mean      11.886348      5.014845
# std        9.599766      2.761507
# min        0.800000      1.000000
# 25%        4.500000      3.000000
# 50%        4.500000      3.000000
# 75%       20.600000      8.000000
# max       31.200000     10.000000
#
# [8 rows x 22 columns]

# %%
braga_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19198 entries, 0 to 19197
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   longitude         19198 non-null  float64
#  1   latitude          19198 non-null  float64
#  2   no2               15287 non-null  float64
#  3   pm10              13761 non-null  float64
#  4   pm25              863 non-null    float64
#  5   pm1               266 non-null    float64
#  6   date              18331 non-null  object
#  7   time              18331 non-null  object
#  8   tempmax           19198 non-null  float64
#  9   tempmin           19198 non-null  float64
#  10  temp              19198 non-null  float64
#  11  feelslike         19198 non-null  float64
#  12  dew               19198 non-null  float64
#  13  humidity          19198 non-null  float64
#  14  severerisk        19198 non-null  float64
#  15  precip            19198 non-null  float64
#  16  snow              19198 non-null  float64
#  17  windspeed         19198 non-null  float64
#  18  sealevelpressure  19198 non-null  float64
#  19  cloudcover        19198 non-null  float64
#  20  visibility        19198 non-null  float64
#  21  solarradiation    19198 non-null  float64
#  22  solarenergy       19198 non-null  float64
#  23  uvindex           19198 non-null  float64
# dtypes: float64(22), object(2)
# memory usage: 3.5+ MB

# %%
print(braga_data.columns,braga_data.shape)
# Out:
# Index(['longitude', 'latitude', 'no2', 'pm10', 'pm25', 'pm1', 'date', 'time',
#        'tempmax', 'tempmin', 'temp', 'feelslike', 'dew', 'humidity',
#        'severerisk', 'precip', 'snow', 'windspeed', 'sealevelpressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex'],
#       dtype='object') (19198, 24)

# %%
# criar um ficheiro para ver os valores de ocorrências para não ser tão repetitivo
with open("../model/datasets/occorrencies.txt", "w+") as f:
    for column in braga_data.columns:
        f.write("Column: " + str(column))
        f.write("\n")
        f.write(str(braga_data[column].value_counts()))
        f.write("\n")
        f.write("-"*50)
        f.write("\n")

# %% [markdown]
# ## Exploração de Dados

# %% [markdown]
# ### Duplicados e Valores nulos

# %%
print(str(braga_data[braga_data.duplicated()])) # Verifica se e quais são os valores duplicados
print("\n")
print(str(braga_data.isna().any())) # Verifica se há valores nulos no dataset
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, no2, pm10, pm25, pm1, date, time, tempmax, tempmin, temp, feelslike, dew, humidity, severerisk, precip, snow, windspeed, sealevelpressure, cloudcover, visibility, solarradiation, solarenergy, uvindex]
# Index: []
#
# [0 rows x 24 columns]
#
#
# longitude           False
# latitude            False
# no2                  True
# pm10                 True
# pm25                 True
# pm1                  True
# date                 True
# time                 True
# tempmax             False
# tempmin             False
# temp                False
# feelslike           False
# dew                 False
# humidity            False
# severerisk          False
# precip              False
# snow                False
# windspeed           False
# sealevelpressure    False
# cloudcover          False
# visibility          False
# solarradiation      False
# solarenergy         False
# uvindex             False
# dtype: bool

# %%
print(braga_data.isna().sum()) # Contagem dos valores em falta do dataset
# Out:
# longitude               0
# latitude                0
# no2                  3911
# pm10                 5437
# pm25                18335
# pm1                 18932
# date                  867
# time                  867
# tempmax                 0
# tempmin                 0
# temp                    0
# feelslike               0
# dew                     0
# humidity                0
# severerisk              0
# precip                  0
# snow                    0
# windspeed               0
# sealevelpressure        0
# cloudcover              0
# visibility              0
# solarradiation          0
# solarenergy             0
# uvindex                 0
# dtype: int64

# %%
sns.heatmap(braga_data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
# Identificar o Intervalo de Latidude e Longitude do dataset
print("Latitude:\n", braga_data['latitude'].min(), braga_data['latitude'].max())
print("Longitude:\n", braga_data['longitude'].min(), braga_data['longitude'].max())

# dar plot às coordenadas num mapa para ver se estão corretas
plt.figure(figsize=(5,5))
sns.scatterplot(x='longitude', y='latitude', data=braga_data)
# Out:
# Latitude:
#  41.449722 41.653315
# Longitude:
#  -8.58779 -8.296389
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# Identificar o Intervalo de Tempo
# Converter a coluna 'data' em datetime
braga_data['date'] = pd.to_datetime(braga_data['date'],format="%Y-%m-%d")
print("Time:\n", braga_data['date'].min(), braga_data['date'].max())
# Out:
# Time:
#  2020-01-01 00:00:00 2022-07-31 00:00:00

# %%
# Gráfico de linhas para ver a evolução dos poluentes ao longo do tempo
# Há uma coluna para cada poluente
pollutants = ['no2', 'pm10', 'pm25', 'pm1']
plt.figure(figsize=(20,10))
for i in range(len(pollutants)):
    plt.subplot(2,2,i+1)
    sns.lineplot(x='date', y=pollutants[i], data=braga_data)
    plt.title(pollutants[i])
    plt.xticks(rotation=45)
plt.tight_layout()

# %%
# obter todas as colunas menos a dos poluentes
columns = braga_data.columns
columns = columns.drop(pollutants)
# remover a coluna 'date' e 'time'
columns = columns.drop(['date', 'time', 'latitude', 'longitude'])

plt.figure(figsize=(40,10))
# 2 colunas e 3 linhas
for i in range(len(columns)):
    plt.subplot(8,2,i+1)
    sns.lineplot(x='date', y=columns[i], data=braga_data)
    plt.title(columns[i])
    plt.xticks(rotation=45)
plt.tight_layout()
# Out:
# /tmp/ipykernel_40631/1123057636.py:14: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Gerar gráficos de densidade para cada coluna que seja numerica
columns = braga_data.columns
columns = columns.drop(pollutants)
columns = columns.drop(['date', 'time', 'latitude', 'longitude'])
plt.figure(figsize=(40,10))
for i in range(len(columns)):
    plt.subplot(8,2,i+1)
    sns.distplot(braga_data[columns[i]])
    plt.title(columns[i])
plt.tight_layout()
# Out:
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /home/purp/anaconda3/envs/deepl/lib/python3.9/site-packages/seaborn/distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])
# /tmp/ipykernel_40631/661376864.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(braga_data[columns[i]])

# %% [markdown]
# ## Outliers

# %%
sns.set_theme(palette="pastel")
# plot outliers boxplot para cada coluna
for column in braga_data.columns:
    if column not in ['date', 'time', 'latitude', 'longitude']:
        plt.figure(figsize=(5,5))
        sns.boxplot(x=braga_data[column])

# %%
# Theoretical Quantile-Quantile Plots
def plot_probplots(columns, df):
    for column in columns:
        plt.figure()
        stats.probplot(df[column], dist="norm", plot=plt)
        plt.title(f"Probability plot of {column}")
    plt.show()

columns = braga_data.columns[1:]
plot_probplots(columns,braga_data)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[79], line 10
#       7     plt.show()
#       9 columns = braga_data.columns[1:]
# ---> 10 plot_probplots(columns,braga_data)
#
# Cell In[79], line 5, in plot_probplots(columns, df)
#       3 for column in columns:
#       4     plt.figure()
# ----> 5     stats.probplot(df[column], dist="norm", plot=plt)
#       6     plt.title(f"Probability plot of {column}")
#       7 plt.show()
#
# File ~/anaconda3/envs/deepl/lib/python3.9/site-packages/scipy/stats/_morestats.py:622, in probplot(x, sparams, dist, fit, plot, rvalue)
#     619 osr = sort(x)
#     620 if fit:
#     621     # perform a linear least squares fit.
# --> 622     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     624 if plot is not None:
#     625     plot.plot(osm, osr, 'bo')
#
# File ~/anaconda3/envs/deepl/lib/python3.9/site-packages/scipy/stats/_stats_mstats_common.py:162, in linregress(x, y, alternative)
#     160 n = len(x)
#     161 xmean = np.mean(x, None)
# --> 162 ymean = np.mean(y, None)
#     164 # Average sums of square differences from the mean
#     165 #   ssxm = mean( (x-mean(x))^2 )
#     166 #   ssxym = mean( (x-mean(x)) * (y-mean(y)) )
#     167 ssxm, ssxym, _, ssym = np.cov(x, y, bias=1).flat
#
# File <__array_function__ internals>:180, in mean(*args, **kwargs)
#
# File ~/anaconda3/envs/deepl/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432, in mean(a, axis, dtype, out, keepdims, where)
#    3429     else:
#    3430         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3432 return _methods._mean(a, axis=axis, dtype=dtype,
#    3433                       out=out, **kwargs)
#
# File ~/anaconda3/envs/deepl/lib/python3.9/site-packages/numpy/core/_methods.py:180, in _mean(a, axis, dtype, out, keepdims, where)
#     177         dtype = mu.dtype('f4')
#     178         is_float16_result = True
# --> 180 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     181 if isinstance(ret, mu.ndarray):
#     182     ret = um.true_divide(
#     183             ret, rcount, out=ret, casting='unsafe', subok=False)
#
# UFuncTypeError: ufunc 'add' cannot use operands with types dtype('<M8[ns]') and dtype('<M8[ns]')

# %% [markdown]
# ## Correlações

# %%
plt.subplots(figsize=(14,8))
sns.heatmap(braga_data.corr(), annot = True, cmap='coolwarm')
# diminuir o tamanho da letra
plt.tick_params(axis='both', which='major', labelsize=10, labelbottom = False, bottom=False, top = False, labeltop=True)
# reduzir simetria
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
# Out:
# /tmp/ipykernel_40631/3852375.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(braga_data.corr(), annot = True, cmap='coolwarm')
